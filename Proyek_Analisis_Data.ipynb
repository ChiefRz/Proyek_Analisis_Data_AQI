# %% [markdown]
# <a href="https://colab.research.google.com/github/ChiefRz/Proyek_Analisis_Data_AQI/blob/main/Proyek_Analisis_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Analisis Data: AIR QUALITY DATASET
# - **Nama:** RHEYZA AVTA NAUFALDY
# - **Email:** rheyzaavtanaufaldy@gmail.com
# - **ID Dicoding:** rheyzaan11

# %% [markdown]
# ## Menentukan Pertanyaan Bisnis

# %% [markdown]
# - Bagaimana perubahan bulanan tingkat PM10 pada setiap stasiun ?
# - Bagaimana kondisi tingkat PM10 antara musim dingin, semi, panas, dan gugur di setiap stasiun?

# %% [markdown]
# ## Import Semua Packages/Library yang Digunakan

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import os
import folium

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# ### Gathering Data

# %%
# Daftar file data pencemaran
data_pencemaran_files = os.listdir('/content/drive/MyDrive/Colab Notebooks/Proyek Analisis Data/dataset/')

data_pencemaran_files

# Inisialisasi dataframe kosong
data_pencemaran = pd.DataFrame()

# Loop untuk membaca data dari setiap file
for file in data_pencemaran_files:
    # Membaca data dari file CSV
    data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Proyek Analisis Data/dataset/' + file)

    # Menambahkan data ke dataframe utama
    data_pencemaran = pd.concat([data_pencemaran, data], ignore_index=True)

data_pencemaran
# Out:
#            No  year  month  day  hour  PM2.5  PM10   SO2   NO2      CO    O3  \
# 0           1  2013      3    1     0    4.0   4.0   4.0   7.0   300.0  77.0
# 1           2  2013      3    1     1    8.0   8.0   4.0   7.0   300.0  77.0
# 2           3  2013      3    1     2    7.0   7.0   5.0  10.0   300.0  73.0
# 3           4  2013      3    1     3    6.0   6.0  11.0  11.0   300.0  72.0
# 4           5  2013      3    1     4    3.0   3.0  12.0  12.0   300.0  72.0
# ...       ...   ...    ...  ...   ...    ...   ...   ...   ...     ...   ...
# 420763  35060  2017      2   28    19   27.0  72.0   8.0  92.0   800.0  16.0
# 420764  35061  2017      2   28    20   47.0  55.0  17.0  86.0  1100.0  19.0
# 420765  35062  2017      2   28    21   18.0  28.0   4.0  30.0   500.0  64.0
# 420766  35063  2017      2   28    22   18.0  20.0   9.0  33.0   500.0  59.0
# 420767  35064  2017      2   28    23   15.0  22.0  13.0  34.0   500.0  60.0
#
# ...

# %% [markdown]
# **Insight:**
# - Diketahui data pada tahun 2017 hanya sampai bulan Februari

# %% [markdown]
# ### Assessing Data

# %% [markdown]
# #### Menilai Tabel data_pencemaran

# %%
data_pencemaran.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 420768 entries, 0 to 420767
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       420768 non-null  int64
#  1   year     420768 non-null  int64
#  2   month    420768 non-null  int64
#  3   day      420768 non-null  int64
#  4   hour     420768 non-null  int64
#  5   PM2.5    412029 non-null  float64
#  6   PM10     414319 non-null  float64
#  7   SO2      411747 non-null  float64
#  8   NO2      408652 non-null  float64
#  9   CO       400067 non-null  float64
#  10  O3       407491 non-null  float64
#  11  TEMP     420370 non-null  float64
#  12  PRES     420375 non-null  float64
#  13  DEWP     420365 non-null  float64
#  14  RAIN     420378 non-null  float64
#  15  wd       418946 non-null  object
#  16  WSPM     420450 non-null  float64
#  17  station  420768 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.8+ MB

# %%
data_pencemaran.isna().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
print("Jumlah Duplikasi : ", data_pencemaran.duplicated().sum())
# Out:
# Jumlah Duplikasi :  0

# %%
data_pencemaran.describe()
# Out:
#                   No           year          month            day  \
# count  420768.000000  420768.000000  420768.000000  420768.000000
# mean    17532.500000    2014.662560       6.522930      15.729637
# std     10122.116943       1.177198       3.448707       8.800102
# min         1.000000    2013.000000       1.000000       1.000000
# 25%      8766.750000    2014.000000       4.000000       8.000000
# 50%     17532.500000    2015.000000       7.000000      16.000000
# 75%     26298.250000    2016.000000      10.000000      23.000000
# max     35064.000000    2017.000000      12.000000      31.000000
#
#                 hour          PM2.5           PM10            SO2  \
# count  420768.000000  412029.000000  414319.000000  411747.000000
# mean       11.500000      79.793428     104.602618      15.830835
# std         6.922195      80.822391      91.772426      21.650603
# min         0.000000       2.000000       2.000000       0.285600
# ...

# %% [markdown]
# ### Cleaning Data

# %% [markdown]
# #### Membersihkan Tabel data_pencemaran

# %% [markdown]
# Missing Value

# %%
data_pencemaran.isna().sum()
# Out:
# No             0
# year           0
# month          0
# day            0
# hour           0
# PM2.5       8739
# PM10        6449
# SO2         9021
# NO2        12116
# CO         20701
# O3         13277
# TEMP         398
# PRES         393
# DEWP         403
# RAIN         390
# wd          1822
# WSPM         318
# station        0
# dtype: int64

# %%
# Menghapus missing value pada kolom PM10
data_pencemaran.dropna(subset=["PM10"], inplace=True)

# %%
# Menghapus baris yang memiliki value year 2017
data_pencemaran = data_pencemaran[data_pencemaran['year'] != 2017]

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Explore Tabel data_pencemaran

# %%
# Konversi tahun ke variabel kategorikal
data_pencemaran.loc[:, 'month'] = data_pencemaran['month'].astype('category')
data_pencemaran.loc[:, 'year'] = data_pencemaran['year'].astype('category')
data_pencemaran.info()

# Memeriksa nilai unik di kolom 'month' setelah penghapusan
print(data_pencemaran['month'].unique())  # Untuk memeriksa nilai unik

# Grouping dan menghitung rata-rata TEMP
data_grouped = data_pencemaran.groupby(['station', 'month', 'year'])['PM10'].mean().reset_index()
data_grouped
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 397554 entries, 0 to 419351
# Data columns (total 18 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   No       397554 non-null  int64
#  1   year     397554 non-null  int64
#  2   month    397554 non-null  int64
#  3   day      397554 non-null  int64
#  4   hour     397554 non-null  int64
#  5   PM2.5    395090 non-null  float64
#  6   PM10     397554 non-null  float64
#  7   SO2      393782 non-null  float64
#  8   NO2      390743 non-null  float64
#  9   CO       382386 non-null  float64
#  10  O3       389353 non-null  float64
#  11  TEMP     397292 non-null  float64
#  12  PRES     397291 non-null  float64
#  13  DEWP     397287 non-null  float64
#  14  RAIN     397295 non-null  float64
#  15  wd       396187 non-null  object
#  16  WSPM     397319 non-null  float64
#  17  station  397554 non-null  object
# dtypes: float64(11), int64(5), object(2)
# memory usage: 57.6+ MB
# ...

# %%
# Membuat Fungsi untuk menentukan musim berdasarkan bulan
def menentukan_musim(month):
    if month in [12, 1, 2]:
        return 'Musim Dingin'
    elif month in [3, 4, 5]:
        return 'Musim Semi'
    elif month in [6, 7, 8]:
        return 'Musim Panas'
    elif month in [9, 10, 11]:
        return 'Musim Gugur'
    else:
        return 'Invalid month'

# Merapkan fungsi untuk menambahkan kolom musim
data_grouped['musim'] = data_grouped['month'].apply(menentukan_musim)

# Mampilkan DataFrame
print(data_grouped)
data_grouped
# Out:
#            station  month  year        PM10         musim
# 0     Aotizhongxin      1  2014  125.670732  Musim Dingin
# 1     Aotizhongxin      1  2015  114.964179  Musim Dingin
# 2     Aotizhongxin      1  2016   86.884511  Musim Dingin
# 3     Aotizhongxin      2  2014  150.735069  Musim Dingin
# 4     Aotizhongxin      2  2015  123.586207  Musim Dingin
# ..             ...    ...   ...         ...           ...
# 547  Wanshouxigong     11  2016  136.377778   Musim Gugur
# 548  Wanshouxigong     12  2013  121.998654  Musim Dingin
# 549  Wanshouxigong     12  2014  111.129363  Musim Dingin
# 550  Wanshouxigong     12  2015  180.304469  Musim Dingin
# 551  Wanshouxigong     12  2016  169.460189  Musim Dingin
#
# [552 rows x 5 columns]
#            station  month  year        PM10         musim
# 0     Aotizhongxin      1  2014  125.670732  Musim Dingin
# 1     Aotizhongxin      1  2015  114.964179  Musim Dingin
# 2     Aotizhongxin      1  2016   86.884511  Musim Dingin
# ...

# %%
# Membuat fungsi untuk mengkategorikan AQI
def calculate_aqi_pm10(concentration):
    # Menentukan batas bawah dan batas atas konsentrasi dan rentang AQI
    BP_low = 55
    BP_high = 154
    I_low = 51
    I_high = 100

    # Hitung AQI dengan menggunakan rumus
    AQI_PM10 = ((concentration - BP_low) / (BP_high - BP_low)) * (I_high - I_low) + I_low
    return AQI_PM10

# Menghitung AQI untuk setiap nilai di kolom 'pm10' dan menambahkannya ke kolom baru 'aqi_pm10'
data_grouped['aqi_pm10'] = data_grouped['PM10'].apply(calculate_aqi_pm10)

# Menampilkan DataFrame
print(data_grouped)
# Out:
#            station  month  year        PM10         musim    aqi_pm10
# 0     Aotizhongxin      1  2014  125.670732  Musim Dingin   85.978443
# 1     Aotizhongxin      1  2015  114.964179  Musim Dingin   80.679240
# 2     Aotizhongxin      1  2016   86.884511  Musim Dingin   66.781223
# 3     Aotizhongxin      2  2014  150.735069  Musim Dingin   98.384024
# 4     Aotizhongxin      2  2015  123.586207  Musim Dingin   84.946708
# ..             ...    ...   ...         ...           ...         ...
# 547  Wanshouxigong     11  2016  136.377778   Musim Gugur   91.277890
# 548  Wanshouxigong     12  2013  121.998654  Musim Dingin   84.160950
# 549  Wanshouxigong     12  2014  111.129363  Musim Dingin   78.781200
# 550  Wanshouxigong     12  2015  180.304469  Musim Dingin  113.019384
# 551  Wanshouxigong     12  2016  169.460189  Musim Dingin  107.652013
#
# [552 rows x 6 columns]

# %%
data_grouped_aqi = data_grouped

# Konversi tahun ke variabel kategorikal
data_grouped_aqi.loc[:, 'year'] = data_grouped_aqi['year'].astype('category')

# Pastikan untuk memeriksa nilai unik di kolom 'year' setelah penghapusan
print(data_grouped_aqi['year'].unique())

# Grouping dan menghitung rata-rata TEMP
data_grouped_aqi = data_grouped_aqi.groupby(['station', 'year'])['aqi_pm10'].mean().reset_index()
data_grouped_aqi
# Out:
# [2014 2015 2016 2013]
#           station  year   aqi_pm10
# 0    Aotizhongxin  2013  79.655928
# 1    Aotizhongxin  2014  84.033077
# 2    Aotizhongxin  2015  79.262817
# 3    Aotizhongxin  2016  70.505994
# 4       Changping  2013  68.919711
# 5       Changping  2014  76.751244
# 6       Changping  2015  70.164366
# 7       Changping  2016  66.395176
# 8        Dingling  2013  62.747008
# 9        Dingling  2014  68.786120
# 10       Dingling  2015  66.112162
# 11       Dingling  2016  63.455943
# 12         Dongsi  2013  75.629594
# 13         Dongsi  2014  81.799801
# 14         Dongsi  2015  79.196621
# 15         Dongsi  2016  74.456523
# 16       Guanyuan  2013  77.095171
# 17       Guanyuan  2014  81.222532
# 18       Guanyuan  2015  76.423646
# 19       Guanyuan  2016  75.449343
# 20        Gucheng  2013  79.479608
# 21        Gucheng  2014  90.143810
# 22        Gucheng  2015  81.349313
# 23        Gucheng  2016  78.468812
# 24        Huairou  2013  71.202368
# ...

# %%
# Mengelompokkan AQI
def air_quality(aqi):
    if aqi <= 50:
        return 'Baik'
    elif aqi <= 100:
        return 'Sedang'
    elif aqi <= 150:
        return 'Tidak Sehat'
    elif aqi <= 200:
        return 'Sangat Tidak Sehat'
    else:
        return 'Berbahaya'

data_grouped_aqi['kualitas_udara'] = data_grouped_aqi['aqi_pm10'].apply(air_quality)

# Menampilkan DataFrame
print(data_grouped_aqi)
# Out:
#           station  year   aqi_pm10 kualitas_udara
# 0    Aotizhongxin  2013  79.655928         Sedang
# 1    Aotizhongxin  2014  84.033077         Sedang
# 2    Aotizhongxin  2015  79.262817         Sedang
# 3    Aotizhongxin  2016  70.505994         Sedang
# 4       Changping  2013  68.919711         Sedang
# 5       Changping  2014  76.751244         Sedang
# 6       Changping  2015  70.164366         Sedang
# 7       Changping  2016  66.395176         Sedang
# 8        Dingling  2013  62.747008         Sedang
# 9        Dingling  2014  68.786120         Sedang
# 10       Dingling  2015  66.112162         Sedang
# 11       Dingling  2016  63.455943         Sedang
# 12         Dongsi  2013  75.629594         Sedang
# 13         Dongsi  2014  81.799801         Sedang
# 14         Dongsi  2015  79.196621         Sedang
# 15         Dongsi  2016  74.456523         Sedang
# 16       Guanyuan  2013  77.095171         Sedang
# 17       Guanyuan  2014  81.222532         Sedang
# ...

# %%
# Menginisiasi data latitude dan longitude
data = {
    'station': ['Aotizhongxin', 'Changping', 'Dingling', 'Dongsi', 'Guanyuan', 'Gucheng', 'Huairou', 'Nongzhanguan', 'Shunyi', 'Tiantan', 'Wanliu', 'Wanshouxigong'],
    'latitude': [39.9092, 40.2000, 40.2350, 39.9330, 39.9510, 39.9130, 40.4300, 39.9320, 40.1300, 39.8840, 39.9790, 39.9050],
    'longitude': [116.3972, 116.2000, 116.1960, 116.4160, 116.3090, 116.2040, 116.6400, 116.4500, 116.6520, 116.4140, 116.3070, 116.3070]
}

df = pd.DataFrame(data)
print(df)
df
# Out:
#           station  latitude  longitude
# 0    Aotizhongxin   39.9092   116.3972
# 1       Changping   40.2000   116.2000
# 2        Dingling   40.2350   116.1960
# 3          Dongsi   39.9330   116.4160
# 4        Guanyuan   39.9510   116.3090
# 5         Gucheng   39.9130   116.2040
# 6         Huairou   40.4300   116.6400
# 7    Nongzhanguan   39.9320   116.4500
# 8          Shunyi   40.1300   116.6520
# 9         Tiantan   39.8840   116.4140
# 10         Wanliu   39.9790   116.3070
# 11  Wanshouxigong   39.9050   116.3070
#           station  latitude  longitude
# 0    Aotizhongxin   39.9092   116.3972
# 1       Changping   40.2000   116.2000
# 2        Dingling   40.2350   116.1960
# 3          Dongsi   39.9330   116.4160
# 4        Guanyuan   39.9510   116.3090
# 5         Gucheng   39.9130   116.2040
# 6         Huairou   40.4300   116.6400
# 7    Nongzhanguan   39.9320   116.4500
# 8          Shunyi   40.1300   116.6520
# 9         Tiantan   39.8840   116.4140
# ...

# %%
AQI_df = pd.merge(df, data_grouped_aqi, on='station', how='outer')
AQI_df
# Out:
#           station  latitude  longitude  year   aqi_pm10 kualitas_udara
# 0    Aotizhongxin   39.9092   116.3972  2013  79.655928         Sedang
# 1    Aotizhongxin   39.9092   116.3972  2014  84.033077         Sedang
# 2    Aotizhongxin   39.9092   116.3972  2015  79.262817         Sedang
# 3    Aotizhongxin   39.9092   116.3972  2016  70.505994         Sedang
# 4       Changping   40.2000   116.2000  2013  68.919711         Sedang
# 5       Changping   40.2000   116.2000  2014  76.751244         Sedang
# 6       Changping   40.2000   116.2000  2015  70.164366         Sedang
# 7       Changping   40.2000   116.2000  2016  66.395176         Sedang
# 8        Dingling   40.2350   116.1960  2013  62.747008         Sedang
# 9        Dingling   40.2350   116.1960  2014  68.786120         Sedang
# 10       Dingling   40.2350   116.1960  2015  66.112162         Sedang
# 11       Dingling   40.2350   116.1960  2016  63.455943         Sedang
# ...

# %%
AQI_all_df = pd.concat([AQI_df, data_grouped])
AQI_all_df
# Out:
#            station  latitude  longitude  year    aqi_pm10 kualitas_udara  \
# 0     Aotizhongxin   39.9092   116.3972  2013   79.655928         Sedang
# 1     Aotizhongxin   39.9092   116.3972  2014   84.033077         Sedang
# 2     Aotizhongxin   39.9092   116.3972  2015   79.262817         Sedang
# 3     Aotizhongxin   39.9092   116.3972  2016   70.505994         Sedang
# 4        Changping   40.2000   116.2000  2013   68.919711         Sedang
# ..             ...       ...        ...   ...         ...            ...
# 547  Wanshouxigong       NaN        NaN  2016   91.277890            NaN
# 548  Wanshouxigong       NaN        NaN  2013   84.160950            NaN
# 549  Wanshouxigong       NaN        NaN  2014   78.781200            NaN
# 550  Wanshouxigong       NaN        NaN  2015  113.019384            NaN
# 551  Wanshouxigong       NaN        NaN  2016  107.652013            NaN
#
#      month        PM10         musim
# 0      NaN         NaN           NaN
# ...

# %%
AQI_all_df.to_csv("/content/drive/MyDrive/Colab Notebooks/Proyek Analisis Data/all_data/AQI_all_df.csv")

# %% [markdown]
# ## Visualization & Explanatory Analysis

# %% [markdown]
# ### Pertanyaan 1:

# %%
data_grouped = AQI_all_df.dropna(subset=['month', 'PM10', 'musim'])
data_grouped
# Out:
#            station  latitude  longitude  year    aqi_pm10 kualitas_udara  \
# 0     Aotizhongxin       NaN        NaN  2014   85.978443            NaN
# 1     Aotizhongxin       NaN        NaN  2015   80.679240            NaN
# 2     Aotizhongxin       NaN        NaN  2016   66.781223            NaN
# 3     Aotizhongxin       NaN        NaN  2014   98.384024            NaN
# 4     Aotizhongxin       NaN        NaN  2015   84.946708            NaN
# ..             ...       ...        ...   ...         ...            ...
# 547  Wanshouxigong       NaN        NaN  2016   91.277890            NaN
# 548  Wanshouxigong       NaN        NaN  2013   84.160950            NaN
# 549  Wanshouxigong       NaN        NaN  2014   78.781200            NaN
# 550  Wanshouxigong       NaN        NaN  2015  113.019384            NaN
# 551  Wanshouxigong       NaN        NaN  2016  107.652013            NaN
#
#      month        PM10         musim
# 0      1.0  125.670732  Musim Dingin
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Aotizhongxin'
year1 = '2013'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan tahun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Changping'
year1 = '2014'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Dingling'
year1 = '2015'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Dongsi'
year1 = '2016'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Guanyuan'
year1 = '2013'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Gucheng'
year1 = '2014'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Huairou'
year1 = '2015'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Nongzhanguan'
year1 = '2016'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Shunyi'
year1 = '2013'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Tiantan'
year1 = '2014'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Wanliu'
year1 = '2015'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name1 = 'Wanshouxigong'
year1 = '2016'

rata_rata_pm10 = data_grouped[data_grouped['station'] == station_name1]
fig = px.line(rata_rata_pm10, x='month', y='PM10', color='year',
              color_discrete_sequence=px.colors.qualitative.Set3)

# Menentukan stasiun yang ingin diberi ketebalan garis berbeda
thick_year = year1
thick_line_width = 5
default_line_width = 2

# Mengupdate ketebalan garis
for trace in fig.data:
    if trace.name == thick_year:
        trace.line.width = thick_line_width
    else:
        trace.line.width = default_line_width

# Atur sumbu x sebagai tipe data kategorikal
fig.update_xaxes(type='category')

# Atur label pada sumbu x
fig.update_xaxes(ticktext=rata_rata_pm10['month'].unique(), tickvals=rata_rata_pm10['month'].unique())

# Menambahkan judul dan label
fig.update_layout(title=f'Rata-Rata PM10 setiap bulan di stasiun {station_name1} pada tahun {year1}',
                  yaxis_title='Rata-Rata PM10',
                  xaxis_title='Bulan',
                  legend_title='Tahun')

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Pertanyaan 2:

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Aotizhongxin'
year2 = 2013

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Changping'
year2 = 2014

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Dingling'
year2 = 2015

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Dongsi'
year2 = 2016

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Guanyuan'
year2 = 2013

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Gucheng'
year2 = 2014

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Huairou'
year2 = 2015

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Nongzhanguan'
year2 = 2016

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Shunyi'
year2 = 2013

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Tiantan'
year2 = 2014

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Wanliu'
year2 = 2015

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Menentukan Stasiun dan Tahun yang ingin di highlight
station_name2 = 'Wanshouxigong'
year2 = 2016

data_filtered_musim = data_grouped[(data_grouped['year'] == year2) & (data_grouped['station'] == station_name2)]

# Grouping dan menghitung rata-rata SO2
rata_rata_musim = data_filtered_musim.groupby(['station', 'musim'])['PM10'].mean().reset_index()

# Membuat plot dengan warna berbeda untuk stasiun yang disoroti
fig = px.bar(rata_rata_musim,
             x='musim',
             y='PM10',
             title=f'Rata-rata PM10 per Musim Tahun {year2} di stasiun {station_name2}',
             labels={'musim': 'Musim', 'PM10': 'Rata-rata PM10'},
             color='musim') # Menambahkan label yang lebih baik

# Menampilkan plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Analisis Lanjutan (Opsional)

# %%
AQI_df = AQI_all_df.dropna(subset=['kualitas_udara'])
AQI_df
# Out:
#           station  latitude  longitude  year   aqi_pm10 kualitas_udara  month  \
# 0    Aotizhongxin   39.9092   116.3972  2013  79.655928         Sedang    NaN
# 1    Aotizhongxin   39.9092   116.3972  2014  84.033077         Sedang    NaN
# 2    Aotizhongxin   39.9092   116.3972  2015  79.262817         Sedang    NaN
# 3    Aotizhongxin   39.9092   116.3972  2016  70.505994         Sedang    NaN
# 4       Changping   40.2000   116.2000  2013  68.919711         Sedang    NaN
# 5       Changping   40.2000   116.2000  2014  76.751244         Sedang    NaN
# 6       Changping   40.2000   116.2000  2015  70.164366         Sedang    NaN
# 7       Changping   40.2000   116.2000  2016  66.395176         Sedang    NaN
# 8        Dingling   40.2350   116.1960  2013  62.747008         Sedang    NaN
# 9        Dingling   40.2350   116.1960  2014  68.786120         Sedang    NaN
# 10       Dingling   40.2350   116.1960  2015  66.112162         Sedang    NaN
# ...

# %%
# Pilih stasiun yang spesifik
nama_stasiun3 = 'Gucheng'
year3 = 2013

# Ambil lokasi dan tahun dari stasiun dan tahun yang dipilih
data_filtered_p = AQI_df[AQI_df['year'] == year3]
station_data = AQI_df[AQI_df['station'] == nama_stasiun3].iloc[0]
location = [station_data['latitude'], station_data['longitude']]

# Membuat peta dengan lokasi stasiun yang dipilih
m = folium.Map(location=location, zoom_start=12,  tiles='CartoDB positron')

# Menambahkan marker ke peta berdasarkan DataFrame
for index, row in data_filtered_p.iterrows():
    if row['kualitas_udara'] == 'Baik':
        color = 'green'
    elif row['kualitas_udara'] == 'Sedang':
        color = 'orange'
    else:  # 'Buruk'
        color = 'red'

    popup_text = f"Station: {row['station']}<br>Tahun: {row['year']}<br>Indeks Kualitas Udara: {row['kualitas_udara']}<br>Rata-Rata PM10/Tahun: {row['aqi_pm10']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        tooltip=row['station'],
        popup=folium.Popup(popup_text, max_width=200),
        icon=folium.Icon(color=color)
    ).add_to(m)

# Menampilkan peta
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
data_filtered_p = AQI_df[AQI_df['year'] == year3]
data_filtered_p
# Out:
#           station  latitude  longitude  year   aqi_pm10 kualitas_udara  month  \
# 0    Aotizhongxin   39.9092   116.3972  2013  79.655928         Sedang    NaN
# 4       Changping   40.2000   116.2000  2013  68.919711         Sedang    NaN
# 8        Dingling   40.2350   116.1960  2013  62.747008         Sedang    NaN
# 12         Dongsi   39.9330   116.4160  2013  75.629594         Sedang    NaN
# 16       Guanyuan   39.9510   116.3090  2013  77.095171         Sedang    NaN
# 20        Gucheng   39.9130   116.2040  2013  79.479608         Sedang    NaN
# 24        Huairou   40.4300   116.6400  2013  71.202368         Sedang    NaN
# 28   Nongzhanguan   39.9320   116.4500  2013  75.157394         Sedang    NaN
# 32         Shunyi   40.1300   116.6520  2013  70.594343         Sedang    NaN
# 36        Tiantan   39.8840   116.4140  2013  77.367569         Sedang    NaN
# 40         Wanliu   39.9790   116.3070  2013  79.339980         Sedang    NaN
# ...

# %% [markdown]
# ## Conclusion

# %% [markdown]
# - Dari hasil yang sudah divisualisasikan diatas, dapat diketahui bahwa Rata-Rata PM10 setiap bulan di semua stasiun dan setiap tahun hampir selalu naik pada bulan ke-9 dan mengalami penurunan pada bulan ke-5
# - Dari hasil yang sudah divisualisasikan diatas, dapat diketahui bahwa Rata-Rata PM10 pada musim Semi di semua stasiun dan setiap tahun selalu mencapai angka 100 dan pada musim Panas sangat jarang yang mencapai angka 100
